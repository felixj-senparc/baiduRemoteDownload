# %%
# !pip install gradio bypy huggingface_hub
# Out:
# Collecting gradio
#   Downloading gradio-4.8.0-py3-none-any.whl (16.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 60.9 MB/s eta 0:00:00
# Collecting bypy
#   Downloading bypy-1.8.2-py2.py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.8/241.8 kB 21.5 MB/s eta 0:00:00
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.19.4)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.2.2)
# Collecting fastapi (from gradio)
#   Downloading fastapi-0.105.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 14.1 MB/s eta 0:00:00
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.7.1 (from gradio)
#   Downloading gradio_client-0.7.1-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 34.1 MB/s eta 0:00:00
# Collecting httpx (from gradio)
#   Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: numpy~=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.23.5)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (9.4.0)
# Collecting pydantic>=2.0 (from gradio)
#   Downloading pydantic-2.5.2-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 28.4 MB/s eta 0:00:00
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart (from gradio)
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.1)
# Requirement already satisfied: requests~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.31.0)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: typer[all]<1.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.5.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.24.0.post1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.7.1->gradio) (2023.6.0)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.7.1->gradio)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 5.9 MB/s eta 0:00:00
# Collecting requests-toolbelt (from bypy)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.4 MB/s eta 0:00:00
# Collecting multiprocess (from bypy)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Collecting annotated-types>=0.4.0 (from pydantic>=2.0->gradio)
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.14.5 (from pydantic>=2.0->gradio)
#   Downloading pydantic_core-2.14.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 66.7 MB/s eta 0:00:00
# Collecting typing-extensions~=4.0 (from gradio)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (2023.11.17)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio) (8.1.7)
# Collecting colorama<0.5.0,>=0.4.3 (from typer[all]<1.0,>=0.9->gradio)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting shellingham<2.0.0,>=1.3.0 (from typer[all]<1.0,>=0.9->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio) (13.7.0)
# Collecting h11>=0.8 (from uvicorn>=0.14.0->gradio)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi->gradio)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.5 MB/s eta 0:00:00
# Collecting httpcore==1.* (from httpx->gradio)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio) (1.3.0)
# Collecting dill>=0.3.7 (from multiprocess->bypy)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio) (1.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.13.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (0.1.2)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.1-py3-none-any.whl size=5579 sha256=e3e37df565e23239d37e6fd31a4503eccc3cc1c88e7a3ad7d5c44340d3cb05e9
#   Stored in directory: /root/.cache/pip/wheels/01/a6/d1/1c0828c304a4283b2c1639a09ad86f83d7c487ef34c6b4a1bf
# Successfully built ffmpy
# Installing collected packages: pydub, ffmpy, websockets, typing-extensions, tomlkit, shellingham, semantic-version, python-multipart, orjson, h11, dill, colorama, annotated-types, aiofiles, uvicorn, starlette, requests-toolbelt, pydantic-core, multiprocess, httpcore, pydantic, httpx, bypy, gradio-client, fastapi, gradio
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# Successfully installed aiofiles-23.2.1 annotated-types-0.6.0 bypy-1.8.2 colorama-0.4.6 dill-0.3.7 fastapi-0.105.0 ffmpy-0.3.1 gradio-4.8.0 gradio-client-0.7.1 h11-0.14.0 httpcore-1.0.2 httpx-0.25.2 multiprocess-0.70.15 orjson-3.9.10 pydantic-2.5.2 pydantic-core-2.14.5 pydub-0.25.1 python-multipart-0.0.6 requests-toolbelt-1.0.0 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.27.0 tomlkit-0.12.0 typing-extensions-4.9.0 uvicorn-0.24.0.post1 websockets-11.0.3

# %%
import os
import shutil
import huggingface_hub as hh
import pandas as pd
from bypy import ByPy

# %% [markdown]
# ### 下载模型

# %%
def format_size(bytes, precision=2):
    """
    Convert a file size in bytes to a human-readable format like KB, MB, GB, etc.
    Huggingface use 1000 not 1024
    """
    units = ["B", "KB", "MB", "GB", "TB", "PB"]
    size = float(bytes)
    index = 0

    while size >= 1000 and index < len(units) - 1:
        index += 1
        size /= 1000

    return f"{size:.{precision}f} {units[index]}"


def list_repo_files_info(repo_id,token=None):
    data_ls = []
    for file in list(hh.list_files_info(repo_id)):
        data_ls.append([file.path,format_size(file.size)])
    files = [file[0] for file in data_ls]
    data = pd.DataFrame(data_ls,columns = ['文件名','大小'])
    return data, files


def download_file(repo_id,filenames):
    print(filenames)
    repo_name = repo_id.replace("/","---")

    for filename in filenames:
        print(filename)
        out = hh.hf_hub_download(repo_id=repo_id,filename=filename,local_dir=f"./download/{repo_name}",local_dir_use_symlinks=False,force_download =True)
    out_path = f"./download/{repo_name}"
    return out_path

# %%
## 设置 repo_id
repo_id = "mistralai/Mixtral-8x7B-v0.1"

# %%
data, filenames = list_repo_files_info(repo_id)
data
# Out:
#                                  文件名         大小
# 0                     .gitattributes    1.52 KB
# 1                          README.md    3.92 KB
# 2                        config.json   720.00 B
# 3                 consolidated.00.pt   12.13 GB
# 4                 consolidated.01.pt   12.13 GB
# 5                 consolidated.02.pt   12.13 GB
# 6                 consolidated.03.pt   12.13 GB
# 7                 consolidated.04.pt   12.13 GB
# 8                 consolidated.05.pt   12.13 GB
# 9                 consolidated.06.pt   12.13 GB
# 10                consolidated.07.pt   12.13 GB
# 11            generation_config.json   116.00 B
# 12  model-00001-of-00019.safetensors    4.89 GB
# 13  model-00002-of-00019.safetensors    4.98 GB
# 14  model-00003-of-00019.safetensors    4.98 GB
# 15  model-00004-of-00019.safetensors    4.90 GB
# 16  model-00005-of-00019.safetensors    4.98 GB
# 17  model-00006-of-00019.safetensors    4.98 GB
# 18  model-00007-of-00019.safetensors    4.90 GB
# 19  model-00008-of-00019.safetensors    4.98 GB
# 20  model-00009-of-00019.safetensors    4.98 GB
# 21  model-00010-of-00019.safetensors    4.90 GB
# 22  model-00011-of-00019.safetensors    4.98 GB
# 23  model-00012-of-00019.safetensors    4.98 GB
# 24  model-00013-of-00019.safetensors    4.98 GB
# 25  model-00014-of-00019.safetensors    4.90 GB
# 26  model-00015-of-00019.safetensors    4.98 GB
# 27  model-00016-of-00019.safetensors    4.98 GB
# 28  model-00017-of-00019.safetensors    4.90 GB
# 29  model-00018-of-00019.safetensors    4.98 GB
# 30  model-00019-of-00019.safetensors    4.22 GB
# 31      model.safetensors.index.json   92.66 KB
# 32           special_tokens_map.json    72.00 B
# 33                    tokenizer.json    1.80 MB
# 34                   tokenizer.model  493.44 KB
# 35             tokenizer_config.json   967.00 B

# %% [markdown]
# ### 可根据自己需求下载对应文件

# %%
filenames = [
    "model-00001-of-00019.safetensors",
    "model-00002-of-00019.safetensors",
    "model-00003-of-00019.safetensors",
    "model-00004-of-00019.safetensors",
    "model-00005-of-00019.safetensors",
    "model-00006-of-00019.safetensors",
    "model-00007-of-00019.safetensors",
    "model-00008-of-00019.safetensors",
    "model-00009-of-00019.safetensors",
    "model-00010-of-00019.safetensors",
    "model-00011-of-00019.safetensors",
    "model-00012-of-00019.safetensors",
    "model-00013-of-00019.safetensors",
    "model-00014-of-00019.safetensors",
    "model-00015-of-00019.safetensors",
    "model-00016-of-00019.safetensors",
    "model-00017-of-00019.safetensors",
    "model-00018-of-00019.safetensors",
    "model-00019-of-00019.safetensors",
    ]

# %%
for i in range(len(filenames)){

}

# %%
out_path = download_file(repo_id,filenames)
# Out:
# ['model-00001-of-00019.safetensors', 'model-00002-of-00019.safetensors', 'model-00003-of-00019.safetensors', 'model-00004-of-00019.safetensors', 'model-00005-of-00019.safetensors', 'model-00006-of-00019.safetensors', 'model-00007-of-00019.safetensors', 'model-00008-of-00019.safetensors', 'model-00009-of-00019.safetensors']
# model-00001-of-00019.safetensors
# model-00001-of-00019.safetensors:   0%|          | 0.00/4.89G [00:00<?, ?B/s]
# model-00002-of-00019.safetensors
# model-00002-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00019.safetensors
# model-00003-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00019.safetensors
# model-00004-of-00019.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00005-of-00019.safetensors
# model-00005-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00006-of-00019.safetensors
# model-00006-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00007-of-00019.safetensors
# model-00007-of-00019.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00008-of-00019.safetensors
# model-00008-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00009-of-00019.safetensors
# model-00009-of-00019.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]

# %%
# !ls -l /content/download/mistralai---Mixtral-8x7B-v0.1/
# Out:
# total 43543900
# -rw-r--r-- 1 root root 4892809584 Dec 12 08:44 model-00001-of-00019.safetensors
# -rw-r--r-- 1 root root 4983004016 Dec 12 08:44 model-00002-of-00019.safetensors
# -rw-r--r-- 1 root root 4983004016 Dec 12 08:45 model-00003-of-00019.safetensors
# -rw-r--r-- 1 root root 4899035200 Dec 12 08:46 model-00004-of-00019.safetensors
# -rw-r--r-- 1 root root 4983004016 Dec 12 08:46 model-00005-of-00019.safetensors
# -rw-r--r-- 1 root root 4983004016 Dec 12 08:47 model-00006-of-00019.safetensors
# -rw-r--r-- 1 root root 4899035248 Dec 12 08:47 model-00007-of-00019.safetensors
# -rw-r--r-- 1 root root 4983004072 Dec 12 08:48 model-00008-of-00019.safetensors
# -rw-r--r-- 1 root root 4983004072 Dec 12 08:48 model-00009-of-00019.safetensors

# %% [markdown]
# ### 上传百度网盘
#
# 百度云开发者平台： https://pan.baidu.com/union
#
# 大小限制
#
# 所有开发者均可接入使用接口，但可上传单个文件大小根据授权用户的身份有不同的限制:
#
# - 普通用户单个上传文件大小上限为4GB
# - 会员用户单个上传文件大小上限为10GB
# - 超级会员用户单个上传文件大小上限为20GB

# %%
def upload_by_file(source_path):
    bp = ByPy()
    dest_path = source_path.split("/")[-1]  # 文件名
    out = bp.upload(
      source_path,
      dest_path
    )
    return out
def upload_by_path(source_path,compress=True):
    bp = ByPy()
    # 创建目录
    dest_path = source_path.split("/")[-1]
    # 压缩
    if compress:
      print("分卷压缩....")
      tar_path =f"{os.getcwd()}/tar/{dest_path}"
      print(tar_path)
      os.system(f"mkdir -p {tar_path}")
      # os.system(f"zip -s 4000M {tar_path}/{dest_path}.zip {source_path}/*")
      os.system(f"tar -cvpf - {source_path}| split  -b 500M -d -a 3 - {tar_path}/{dest_path}")
      source_path = tar_path
    print("上传百度云....")
    bp.mkdir(dest_path)
    # 同步目录
    out = bp.syncup(
      source_path,
      dest_path,
      deleteremote=True
    )
    return out

# %%
# bp.upload??

# %%
bp = ByPy()
# 目前网盘文件位置
print(bp.list())
# Out:
# /apps/bypy ($t $f $s $m $d):
# D .config 0 2023-12-12, 08:37:11
# 0

# %%
# !ls -lh /content/download/mistralai---Mixtral-8x7B-v0.1/
# Out:
# total 42G
# -rw-r--r-- 1 root root 4.6G Dec 12 08:44 model-00001-of-00019.safetensors
# -rw-r--r-- 1 root root 4.7G Dec 12 08:44 model-00002-of-00019.safetensors
# -rw-r--r-- 1 root root 4.7G Dec 12 08:45 model-00003-of-00019.safetensors
# -rw-r--r-- 1 root root 4.6G Dec 12 08:46 model-00004-of-00019.safetensors
# -rw-r--r-- 1 root root 4.7G Dec 12 08:46 model-00005-of-00019.safetensors
# -rw-r--r-- 1 root root 4.7G Dec 12 08:47 model-00006-of-00019.safetensors
# -rw-r--r-- 1 root root 4.6G Dec 12 08:47 model-00007-of-00019.safetensors
# -rw-r--r-- 1 root root 4.7G Dec 12 08:48 model-00008-of-00019.safetensors
# -rw-r--r-- 1 root root 4.7G Dec 12 08:48 model-00009-of-00019.safetensors

# %%
out_path = "./download/cgisky---RWKV-safetensors-fp16"

# %%
dest_path = out_path.split("/")[-1]
print("分卷压缩....")
tar_path =f"{os.getcwd()}/tar/{dest_path}"
print(tar_path)
os.system(f"mkdir -p {tar_path}")
# os.system(f"zip -s 4000M {tar_path}/{dest_path}.zip {source_path}/*")
os.system(f"tar -cvpf - {out_path}| split  -b 500M -d -a 3 - {tar_path}/{dest_path}")
source_path = tar_path
# Out:
# 分卷压缩....
# /content/tar/cgisky---RWKV-safetensors-fp16

# %%
source_path
# Out:
# '/content/tar/cgisky---RWKV-safetensors-fp16'

# %%
# !cd /content/download/mistralai---Mixtral-8x7B-v0.1/ && echo $PWD & bypy upload
# Out:
# /content/download/mistralai---Mixtral-8x7B-v0.1
# <I> [08:36:44] Remote file '/apps/bypy/.config/.last_opt_in_prompt.yaml' exists and is the same, skip uploading
# <E> [08:38:02] Waiting 10 seconds before retrying...
# <E> [08:38:12] Request Try #2 / 5
# <E> [08:38:13] Waiting 20 seconds before retrying...
# <E> [08:38:33] Request Try #3 / 5
# <E> [08:38:35] Waiting 30 seconds before retrying...
# Signal 2 received, Abort

# %%
# !cd /content/tar/ & echo $PWD & bypy upload
# !bypy upload
# Out:
# /content
# <I> [15:52:29] Remote file '/apps/bypy/.config/.last_opt_in_prompt.yaml' exists and is the same, skip uploading
# <I> [15:52:30] Remote file '/apps/bypy/.config/.last_survey_prompt.yaml' exists and is the same, skip uploading
# <I> [15:52:31] Remote file '/apps/bypy/.config/.last_update_check.json' exists and is the same, skip uploading
# <I> [15:52:32] Remote file '/apps/bypy/.config/active_config' exists and is the same, skip uploading
# <I> [15:52:33] Remote file '/apps/bypy/.config/config_sentinel' exists and is the same, skip uploading
# <I> [15:52:34] Remote file '/apps/bypy/.config/default_configs.db' exists and is the same, skip uploading
# <I> [15:52:35] Remote file '/apps/bypy/.config/gce' exists and is the same, skip uploading
# <I> [15:52:35] Remote file '/apps/bypy/.config/logs/2023.11.29/20.28.33.540311.log' exists and is the same, skip uploading
# <I> [15:52:36] Remote file '/apps/bypy/.config/logs/2023.11.29/20.31.28.293116.log' exists and is the same, skip uploading
# <I> [15:52:38] Remote file '/apps/bypy/.config/logs/2023.11.29/20.31.38.281573.log' exists and is the same, skip uploading
# Signal 2 received, Abort

# %%
source_path = "/content/download/mistralai---Mixtral-8x7B-v0.1/"
# 上传文件夹
# 如果单个文件大小小于 4G 则无需压缩
upload_by_path(source_path)
# Out:
# 分卷压缩....
# /content/tar/
# 上传百度云....
# <E> [09:05:17] Waiting 10 seconds before retrying...
# <E> [09:05:27] Request Try #2 / 5
# <E> [09:05:29] Waiting 20 seconds before retrying...
# <E> [09:05:49] Request Try #3 / 5
# <E> [09:05:51] Waiting 30 seconds before retrying...
# <E> [09:06:21] Request Try #4 / 5
# <E> [09:06:23] Waiting 40 seconds before retrying...
# <E> [09:07:03] Request Try #5 / 5
# <E> [09:07:05] Maximum number (5) of tries failed.
# [====================] 100% (500.0MB/500.0MB) ETA:  (464kB/s, 18m24s gone)
# Combining the following MD5 slices:
# fba0db5d24621dc5ed2b2381b94d2300
# 05d4de37d67ec6cd09c7547a2bd8fd26
# f1136f2d33fde2b2bbd747d3cecc7c9d
# 019583115eb6ef97ff6a0368e5d65c10
# 96b4908edf2b07876ee032272d979425
# 2648750ef1317cba645ed5e3f8f9329c
# 5c76e1044ab283eaa2b8268fc464b4c5
# 076a8fdaa611ec27cb55cd04ca1714e3
# 9790eb7918f16e82dc9e46af7089ab3f
# 2e62bd9b97468aae9631b04677df54cf
# 6ebcb4ec16c562a2a177354242a4e3e1
# 627cc8dc38d64a8a98d3fc11d3f0c07f
# f83913aff003955cf3c3f05498701ffc
# cb65581ade4b7e82f41887f88e8cd4d9
# 7e9fa6bc2a6967761e0561e629d756d9
# 35904947f3d6a382d13df7d7e0827b2d
# 8e973e1d4ed668b0e000d4c84f392720
# a25b71fc0832c1a0a05d0d077ea87beb
# df976ce11d8bc5551b1bd9820cd2afd2
# bcbe646d0a8aade0292381de9d2195bb
# a81b1aa192782029a3ac045f87f6d5b6
# 51d46cec4b498c00bd6112c8f47722b5
# 213ea879ea21fff500e18c17df46a070
# 1cef7073a2bc1ff8c907b132bd3191a4
# 7adcb77bce5817e222f45286063461ba
# <I> [09:25:32] Local and remote file hash DOESN'T match
# <E> [09:25:32] '/content/tar/000' =C=> '/apps/bypy/000' FAILED.
# <E> [09:25:32] Failed to save Hash Cache.
# Exception:
# <class 'OSError'> - [Errno 28] No space left on device
# Stack:
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 619, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 685, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 738, in _run_callback
#     ret = callback()
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 825, in inner
#     self.ctx_run(self.run)
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#     yielded = self.gen.send(value)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#     self.do_execute(
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-23-825032888416>", line 4, in <cell line: 4>
#     upload_by_path(source_path)
#   File "<ipython-input-9-aa64c9dc99b5>", line 25, in upload_by_path
#     out = bp.syncup(
#   File "/usr/local/lib/python3.10/dist-packages/bypy/bypy.py", line 3025, in syncup
#     subresult = self._syncup_single(localdir, rpath, compare_result)
#   File "/usr/local/lib/python3.10/dist-packages/bypy/bypy.py", line 2988, in _syncup_single
#     subresult = self._syncup_local_one(rpath, localdir, l)
#   File "/usr/local/lib/python3.10/dist-packages/bypy/bypy.py", line 2952, in _syncup_local_one
#     subresult = self._upload_file(lcpath, rcpath)
#   File "/usr/local/lib/python3.10/dist-packages/bypy/bypy.py", line 1814, in _upload_file
#     result = self._rapidupload_file(localpath, remotepath, ondup)
#   File "/usr/local/lib/python3.10/dist-packages/bypy/bypy.py", line 1699, in _rapidupload_file
#     self._get_hashes_for_rapidupload(lpath, setlocalfile)
#   File "/usr/local/lib/python3.10/dist-packages/bypy/bypy.py", line 1695, in _get_hashes_for_rapidupload
#     self._current_file_slice_md5 = slice_md5(self._current_file)
#   File "/usr/local/lib/python3.10/dist-packages/bypy/cached.py", line 92, in __call__
#     self._store(info, path, result)
#   File "/usr/local/lib/python3.10/dist-packages/bypy/cached.py", line 127, in _store
#     cached.savecache()
#   File "/usr/local/lib/python3.10/dist-packages/bypy/cached.py", line 230, in savecache
#     perr("Failed to save Hash Cache.\n{}".format(formatex(ex)))
#   File "/usr/local/lib/python3.10/dist-packages/bypy/util.py", line 73, in formatex
#     type(ex), ex, ''.join(traceback.format_stack()))
#
# <E> [09:25:37] Waiting 10 seconds before retrying...
# <E> [09:25:47] Request Try #2 / 5
# <E> [09:25:48] Waiting 20 seconds before retrying...
# <E> [09:26:08] Request Try #3 / 5
# <E> [09:26:09] Waiting 30 seconds before retrying...
# <E> [09:26:39] Request Try #4 / 5
# <E> [09:26:41] Waiting 40 seconds before retrying...
# <E> [09:27:21] Request Try #5 / 5
# <E> [09:27:22] Maximum number (5) of tries failed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-825032888416> in <cell line: 4>()
#       2 # 上传文件夹
#       3 # 如果单个文件大小小于 4G 则无需压缩
# ----> 4 upload_by_path(source_path)
#
# <ipython-input-9-aa64c9dc99b5> in upload_by_path(source_path, compress)
#      23     bp.mkdir(dest_path)
#      24     # 同步目录
# ---> 25     out = bp.syncup(
#      26       source_path,
#      27       dest_path,
#
# /usr/local/lib/python3.10/dist-packages/bypy/bypy.py in syncup(self, localdir, remotedir, deleteremote)
#    3023                                 result = subresult
#    3024                 else:
# -> 3025                         subresult = self._syncup_single(localdir, rpath, compare_result)
#    3026                         if subresult != const.ENoError:
#    3027                                 result = subresult
#
# /usr/local/lib/python3.10/dist-packages/bypy/bypy.py in _syncup_single(self, localdir, rpath, compare_result)
#    2986                                 result = subresult
#    2987                 for l in local:
# -> 2988                         subresult = self._syncup_local_one(rpath, localdir, l)
#    2989                         if subresult != const.ENoError:
#    2990                                 result = subresult
#
# /usr/local/lib/python3.10/dist-packages/bypy/bypy.py in _syncup_local_one(self, rpath, localdir, l)
#    2950                 self._isrev = False
#    2951                 if t == 'F':
# -> 2952                         subresult = self._upload_file(lcpath, rcpath)
#    2953                         if subresult != const.ENoError:
#    2954                                 result = subresult
#
# /usr/local/lib/python3.10/dist-packages/bypy/bypy.py in _upload_file(self, localpath, remotepath, ondup)
#    1829                                                 # slice them using slice size
#    1830                                                 self.pd("'{}' is being slicing uploaded.".format(self._current_file))
# -> 1831                                                 result = self._upload_file_slices(localpath, remotepath, ondup)
#    1832                                         else:
#    1833                                                 result = const.EFileTooBig
#
# /usr/local/lib/python3.10/dist-packages/bypy/bypy.py in _upload_file_slices(self, localpath, remotepath, ondup)
#    1629                                 j = 0
#    1630                                 while True:
# -> 1631                                         ec = self._upload_slice(remotepath)
#    1632                                         if ec == const.ENoError:
#    1633                                                 self.pd("Slice MD5 match, continuing next slice")
#
# /usr/local/lib/python3.10/dist-packages/bypy/bypy.py in _upload_slice(self, remotepath)
#    1529 			'type' : 'tmpfile'}
#    1530
# -> 1531 		return self._stream_upload(self._current_slice,
#    1532 				pars, self._upload_slice_act, remotepath)
#    1533
#
# /usr/local/lib/python3.10/dist-packages/bypy/bypy.py in _stream_upload(self, fo, pars, act, remotepath, url, uploadfilename)
#    1520 			'file': (uploadfilename, fo, 'application/octet-stream')})
#    1521                 headers = {"Content-Type": form.content_type}
# -> 1522 		return self._post(url,
#    1523                         pars, act, remotepath,
#    1524 			headers=headers, data=form)
#
# /usr/local/lib/python3.10/dist-packages/bypy/bypy.py in _post(self, url, pars, act, actargs, retry, addtoken, dumpex, **kwargs)
#     883
#     884         def _post(self, url, pars, act, actargs = None, retry = True, addtoken = True, dumpex = True, **kwargs):
# --> 885                 return self._request(url, pars, act, 'POST', actargs, retry, addtoken, dumpex, **kwargs)
#     886
#     887         # direction: True - upload, False - download
#
# /usr/local/lib/python3.10/dist-packages/bypy/bypy.py in _request(self, url, pars, act, method, actargs, retry, addtoken, dumpex, **kwargs)
#     858                 i = 0
#     859                 while True:
# --> 860                         result = self._request_work(url, pars, act, method, actargs, addtoken, dumpex, **kwnew)
#     861                         i += 1
#     862                         # only ERequestFailed needs retry, other error still directly return
#
# /usr/local/lib/python3.10/dist-packages/bypy/bypy.py in _request_work(self, url, pars, act, method, actargs, addtoken, dumpex, **kwargs)
#     673                         self.pd("Params: {}".format(pars))
#     674
# --> 675                         r = self._requester.request(method, url, params = parsnew, timeout = self._timeout, verify = self._checkssl, **kwargs)
#     676                         self.response = r
#     677                         sc = r.status_code
#
# /usr/local/lib/python3.10/dist-packages/bypy/requester.py in request(cls, method, url, **kwargs)
#     103                 for k,v in cls.options.items():
#     104                         kwargs.setdefault(k, v)
# --> 105                 return requests.request(method, url, **kwargs)
#     106
#     107         @classmethod
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     495         # urllib3.request. It also calls makefile (recv) on the socket.
#     496         try:
# --> 497             conn.request(
#     498                 method,
#     499                 url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     407                     self.send(b"%x\r\n%b\r\n" % (len(chunk), chunk))
#     408                 else:
# --> 409                     self.send(chunk)
#     410
#     411         # Regardless of whether we have a body or not, if we're in
#
# /usr/lib/python3.10/http/client.py in send(self, data)
#     997         sys.audit("http.client.send", self, data)
#     998         try:
# --> 999             self.sock.sendall(data)
#    1000         except TypeError:
#    1001             if isinstance(data, collections.abc.Iterable):
#
# /usr/lib/python3.10/ssl.py in sendall(self, data, flags)
#    1264                 amount = len(byte_view)
#    1265                 while count < amount:
# -> 1266                     v = self.send(byte_view[count:])
#    1267                     count += v
#    1268         else:
#
# /usr/lib/python3.10/ssl.py in send(self, data, flags)
#    1233                     "non-zero flags not allowed in calls to send() on %s" %
#    1234                     self.__class__)
# -> 1235             return self._sslobj.write(data)
#    1236         else:
#    1237             return super().send(data, flags)
#
# KeyboardInterrupt:

# %%
source_path = "/content/download/mistralai---Mixtral-8x7B-v0.1/"
upload_by_file(source_path)

# %%
# !rm -rf /content/download/*
# !rm -rf /content/tar/*
